# %% [markdown]
# # Homework 6 - Chapter 11

# %% [markdown]
# - Due Date: Friday, March 6th no later than 11:59 p.m.
# - Partner Information: Learning to collaborate with others is an important skill and one that employers value.
# To receive credit, this assignment requires you to partner with a classmate and submit one solution for the two of you.
# - Submission Instructions: Upload your solution, entitled **YourFirstName-YourLastName-PartnerFirstName-PartnerLastName-Homework6.ipynb** to the Canvas Homework 6 Dropbox.
# **Note**: only one person needs to submit a solution. If you and your partner both submit a solution, the submission that will be graded is the one from the partner whose last name comes alphabetically first.
# - Deadline Reminder: Once the submission deadline passes, Canvas will no longer accept your submission and you will no longer be able to earn credit. Thus, if you are not able to fully complete the assignment, submit whatever you have before the deadline so that partial credit can be earned.

# %% [markdown]
# ## Starting Code

# %%
from datascience import *
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plots

# %% [markdown]
# Download the file [Valve_Player_Data.csv]()
# into the same directory as this Jupyter notebook.

# %%
# Place the csv file in the same directory as your solution
steam_games = Table().read_table("Valve_Player_Data.csv")
steam_games.show(10)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Month</th> <th>Year</th> <th>Avg_players</th> <th>Gain</th> <th>Percent_Gain</th> <th>Peak_Players</th> <th>Game_Name</th> <th>monthly_rank</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>January</td> <td>2019</td> <td>401367     </td> <td>5857.61 </td> <td>+1.48%      </td> <td>684511      </td> <td>Counter Strike: Global Offensive</td> <td>3           </td>
#         </tr>
#         <tr>
#             <td>January</td> <td>2019</td> <td>475747     </td> <td>36379.2 </td> <td>+8.28%      </td> <td>874888      </td> <td>Dota 2                          </td> <td>2           </td>
#         </tr>
#         <tr>
#             <td>January</td> <td>2019</td> <td>497803     </td> <td>24262   </td> <td>+5.12%      </td> <td>1084606     </td> <td>PUBG: Battlegrounds             </td> <td>1           </td>
#         </tr>
#         <tr>
#             <td>January</td> <td>2019</td> <td>50511.3    </td> <td>-81.11  </td> <td>-0.16%      </td> <td>66649       </td> <td>Team Fortress 2                 </td> <td>7           </td>
#         </tr>
#         <tr>
#             <td>January</td> <td>2019</td> <td>59851.2    </td> <td>4209.87 </td> <td>+7.57%      </td> <td>118210      </td> <td>Grand Theft Auto V              </td> <td>5           </td>
#         </tr>
#         <tr>
#             <td>January</td> <td>2019</td> <td>46201.3    </td> <td>3579.02 </td> <td>+8.40%      </td> <td>85208       </td> <td>Rust                            </td> <td>8           </td>
#         </tr>
#         <tr>
#             <td>January</td> <td>2019</td> <td>52754.5    </td> <td>-973.04 </td> <td>-1.81%      </td> <td>82266       </td> <td>Warframe                        </td> <td>6           </td>
#         </tr>
#         <tr>
#             <td>January</td> <td>2019</td> <td>79175.8    </td> <td>8310.43 </td> <td>+11.73%     </td> <td>137434      </td> <td>Tom Clancy's Rainbow Six Seige  </td> <td>4           </td>
#         </tr>
#         <tr>
#             <td>January</td> <td>2019</td> <td>42307.9    </td> <td>4337.19 </td> <td>+11.42%     </td> <td>97088       </td> <td>Monster Hunter: World           </td> <td>9           </td>
#         </tr>
#         <tr>
#             <td>January</td> <td>2019</td> <td>36766.3    </td> <td>-14555.6</td> <td>-28.36%     </td> <td>77233       </td> <td>Path of Exile                   </td> <td>10          </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (320 rows omitted)</p>

# %% [markdown]
# ## Question 1 - 1 Point

# %% [markdown]
# Steam is an online marketplace where PC gamers can purchase and play a multitude of games. During the Covid-19 pandemic, Steam saw a record number of players. For this assignment, we only want to analyze values from 2020, a time when Steam saw record growth.
#
# Create a table called **steam_2020** that only contains values that are from the year 2020. Display the first 8 values of this table.

# %%
# Place answer here.

steam_2020 = steam_games.where("Year", are.equal_to(2020))
steam_2020.show(8)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Month</th> <th>Year</th> <th>Avg_players</th> <th>Gain</th> <th>Percent_Gain</th> <th>Peak_Players</th> <th>Game_Name</th> <th>monthly_rank</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>January</td> <td>2020</td> <td>501196     </td> <td>44494.4 </td> <td>+9.74%      </td> <td>817229      </td> <td>Counter Strike: Global Offensive</td> <td>1           </td>
#         </tr>
#         <tr>
#             <td>January</td> <td>2020</td> <td>378925     </td> <td>-5254.32</td> <td>-1.37%      </td> <td>616415      </td> <td>Dota 2                          </td> <td>2           </td>
#         </tr>
#         <tr>
#             <td>January</td> <td>2020</td> <td>275363     </td> <td>-33082.4</td> <td>-10.73%     </td> <td>645414      </td> <td>PUBG: Battlegrounds             </td> <td>3           </td>
#         </tr>
#         <tr>
#             <td>January</td> <td>2020</td> <td>59597.9    </td> <td>-2098.02</td> <td>-3.40%      </td> <td>76738       </td> <td>Team Fortress 2                 </td> <td>8           </td>
#         </tr>
#         <tr>
#             <td>January</td> <td>2020</td> <td>111300     </td> <td>13522.5 </td> <td>+13.83%     </td> <td>214796      </td> <td>Grand Theft Auto V              </td> <td>5           </td>
#         </tr>
#         <tr>
#             <td>January</td> <td>2020</td> <td>51620.4    </td> <td>2525.55 </td> <td>+5.14%      </td> <td>97340       </td> <td>Rust                            </td> <td>9           </td>
#         </tr>
#         <tr>
#             <td>January</td> <td>2020</td> <td>65955.1    </td> <td>-26215.9</td> <td>-28.44%     </td> <td>108724      </td> <td>Destiny 2                       </td> <td>7           </td>
#         </tr>
#         <tr>
#             <td>January</td> <td>2020</td> <td>94185.8    </td> <td>15957.1 </td> <td>+20.40%     </td> <td>157948      </td> <td>Tom Clancy's Rainbow Six Seige  </td> <td>6           </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (112 rows omitted)</p>

# %% [markdown]
# ## Question 2 - 2 Points

# %% [markdown]
# Steam records the average number of players per game each month. For this assignment, we are analyzing the popularity of the game **Counter Strike: Global Offensive**, a competitive FPS game. Create a function that randomly picks one of the games in each of the 12 months, then simulate this selection 2,000 times. Save the results in a table called **simulations**, and display the first 10 rows of the table.
#
# **Hint:** The simulations table should have 12 columns, each representing one of the different months. A list of the months has been provided.

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %%
# Place answer here.

import random


def get_month(table):
    games = table.column("Game_Name")
    return random.choice(games)

simulations = Table()
for month in months:
    rows = make_array()
    month_table = steam_2020.where("Month", month)
    for i in range(2000):
        assigned = get_month(month_table)
        rows = np.append(rows, assigned)
    simulations = simulations.with_column(month, rows)


simulations.show(10)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>January</th> <th>February</th> <th>March</th> <th>April</th> <th>May</th> <th>June</th> <th>July</th> <th>August</th> <th>September</th> <th>October</th> <th>November</th> <th>December</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Counter Strike: Global Offensive</td> <td>Tom Clancy's Rainbow Six Seige  </td> <td>Tom Clancy's Rainbow Six Seige</td> <td>Football Manager 2020           </td> <td>PUBG: Battlegrounds             </td> <td>Terraria           </td> <td>Tom Clancy's Rainbow Six Seige</td> <td>Football Manager 2020           </td> <td>Fall Guys: Ultimate Knockout</td> <td>Tom Clancy's Rainbow Six Seige  </td> <td>Rocket League        </td> <td>Rocket League                   </td>
#         </tr>
#         <tr>
#             <td>Team Fortress 2                 </td> <td>Dota 2                          </td> <td>Monster Hunter: World         </td> <td>Dota 2                          </td> <td>Football Manager 2020           </td> <td>PUBG: Battlegrounds</td> <td>Tom Clancy's Rainbow Six Seige</td> <td>Tom Clancy's Rainbow Six Seige  </td> <td>Destiny 2                   </td> <td>Football Manager 2020           </td> <td>Rust                 </td> <td>Team Fortress 2                 </td>
#         </tr>
#         <tr>
#             <td>Grand Theft Auto V              </td> <td>Counter Strike: Global Offensive</td> <td>Monster Hunter: World         </td> <td>ARK: Survival Evolved           </td> <td>Grand Theft Auto V              </td> <td>PUBG: Battlegrounds</td> <td>ARK: Survival Evolved         </td> <td>Grand Theft Auto V              </td> <td>PUBG: Battlegrounds         </td> <td>Dota 2                          </td> <td>Team Fortress 2      </td> <td>Dota 2                          </td>
#         </tr>
#         <tr>
#             <td>The Witcher 3: Wild Hunt        </td> <td>Team Fortress 2                 </td> <td>Dota 2                        </td> <td>ARK: Survival Evolved           </td> <td>Counter Strike: Global Offensive</td> <td>Team Fortress 2    </td> <td>Rust                          </td> <td>Fall Guys: Ultimate Knockout    </td> <td>PUBG: Battlegrounds         </td> <td>Team Fortress 2                 </td> <td>Team Fortress 2      </td> <td>Grand Theft Auto V              </td>
#         </tr>
#         <tr>
#             <td>The Witcher 3: Wild Hunt        </td> <td>Counter Strike: Global Offensive</td> <td>Monster Hunter: World         </td> <td>Counter Strike: Global Offensive</td> <td>Rust                            </td> <td>Team Fortress 2    </td> <td>PUBG: Battlegrounds           </td> <td>Team Fortress 2                 </td> <td>Football Manager 2020       </td> <td>Rocket League                   </td> <td>ARK: Survival Evolved</td> <td>Counter Strike: Global Offensive</td>
#         </tr>
#         <tr>
#             <td>Destiny 2                       </td> <td>Tom Clancy's Rainbow Six Seige  </td> <td>Dota 2                        </td> <td>Rust                            </td> <td>Team Fortress 2                 </td> <td>Dota 2             </td> <td>Football Manager 2020         </td> <td>Fall Guys: Ultimate Knockout    </td> <td>Fall Guys: Ultimate Knockout</td> <td>Tom Clancy's Rainbow Six Seige  </td> <td>Grand Theft Auto V   </td> <td>Dota 2                          </td>
#         </tr>
#         <tr>
#             <td>Team Fortress 2                 </td> <td>ARK: Survival Evolved           </td> <td>Tom Clancy's Rainbow Six Seige</td> <td>PUBG: Battlegrounds             </td> <td>Football Manager 2020           </td> <td>Grand Theft Auto V </td> <td>Destiny 2                     </td> <td>Tom Clancy's Rainbow Six Seige  </td> <td>Fall Guys: Ultimate Knockout</td> <td>Rust                            </td> <td>PUBG: Battlegrounds  </td> <td>Apex Legends                    </td>
#         </tr>
#         <tr>
#             <td>Destiny 2                       </td> <td>Grand Theft Auto V              </td> <td>ARK: Survival Evolved         </td> <td>Football Manager 2020           </td> <td>ARK: Survival Evolved           </td> <td>PUBG: Battlegrounds</td> <td>PUBG: Battlegrounds           </td> <td>Team Fortress 2                 </td> <td>Football Manager 2020       </td> <td>Counter Strike: Global Offensive</td> <td>Rust                 </td> <td>Team Fortress 2                 </td>
#         </tr>
#         <tr>
#             <td>Dota 2                          </td> <td>Team Fortress 2                 </td> <td>PUBG: Battlegrounds           </td> <td>Dota 2                          </td> <td>Grand Theft Auto V              </td> <td>Terraria           </td> <td>Team Fortress 2               </td> <td>Counter Strike: Global Offensive</td> <td>Fall Guys: Ultimate Knockout</td> <td>Football Manager 2020           </td> <td>Dota 2               </td> <td>Team Fortress 2                 </td>
#         </tr>
#         <tr>
#             <td>Dota 2                          </td> <td>Tom Clancy's Rainbow Six Seige  </td> <td>Destiny 2                     </td> <td>Team Fortress 2                 </td> <td>Dota 2                          </td> <td>Team Fortress 2    </td> <td>Football Manager 2020         </td> <td>Tom Clancy's Rainbow Six Seige  </td> <td>PUBG: Battlegrounds         </td> <td>Football Manager 2020           </td> <td>Dota 2               </td> <td>Cyberpunk 2077                  </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (1990 rows omitted)</p>

# %% [markdown]
# ## Question 3a - 2 Points

# %% [markdown]
# Using the **simulations** table created in Question 2, display a histogram showing the distribution of months Counter Strike: Global Offensive was the top ranked game. The bins for the histogram should be the number of months (0-12) where Counter Strike: Global Offensive was the top ranked game that specific number of times.  Make the histogram as readable as possible.

# %%
months_idx = []
for i in range(1,2000):
    games = np.array(simulations.row(i))
    count = np.count_nonzero(games == "Counter Strike: Global Offensive")
    months_idx.append(count)
cs = Table().with_column("Count",months_idx)

cs.hist("Count", bins=np.arange(-0.5,13,1))
plots.title("Number of Times that Counter Strike: Global Offensive was the Simulated Top Ranked Game")
plots.xlabel("Number of Months")
plots.ylim(-.01)
plots.show()

# %% [markdown]
# ## Question 3b - 1 Point

# %% [markdown]
# Formulate a **null hypothesis** about the number of times
# that Counter Strike: Global Offensive is expected to be the top-ranked game.
# (Hint: A null hypothesis assumes that outcomes are determined purely by chance.)

# %% [markdown]
# **Answer** - Counter Strike: Global Offensive has no special advantage over other games to be the top ranked game in any given month.

# %% [markdown]
# ## Question 3c - 1 Point

# %% [markdown]
# In reality, Counter Strike: Global Offensive was the top-ranked game all twelve months.
# Display the histogram from Question 3a but this time add a red dot at coordinate (12, 0)
# to indicate the actual number of times that CS:GO was the top-ranked game.  Make
# the histogram as readable as possible.

# %%
cs.hist("Count", bins=np.arange(-0.5,13,1))
plots.scatter(12, 0, color='red', s=30)
plots.ylim(-.01)
plots.title("Number of Times that Counter Strike: Global Offensive was the Simulated Top Ranked Game")
plots.xlabel("Number of Months")
plots.show()

# %% [markdown]
# ## Question 3d - 1 Point

# %% [markdown]
# Calculate a p-value that uses 12 as the **observed statistic**. Display the value as a percentage
# with 1 digit to the right of the decimal, e.g. "*The p-value is 0.3%*"

# %%
observed_statistic = 12
percent = 100 * (np.count_nonzero(cs.column("Count") >= observed_statistic) / cs.num_rows)
print(f"The p-value is {percent:.1f}%")
# Out:
# The p-value is 0.0%

# %% [markdown]
# Based on the calculated p-value, should the **null hypothesis** be accepted or rejected?  Explain your answer.

# %% [markdown]
# **Answer -** With a p-value of 0.0% we would reject the null hypothesis. This is because under the assumptions of the null hypothesis, it is extremely unlikely to get a value as large as the observed statistic that we actually saw. This provides strong evidence that Counter Strike: Global Offensive has some advantage over other games. It appears as #1 ranked game of the month too many times to be considered chance.

# %% [markdown]
# ## Question 4 - 2 Points

# %% [markdown]
# Discover something insightful with the provided data set. Explain what you have done and why it is insightful.

# %%
top_games = steam_games.where("monthly_rank", 1)
abv_months = top_games.with_column("Abv Month", [m[:3] for m in top_games.column("Month")])
top_2019 = abv_months.where("Year", 2019)
top_2020 = abv_months.where("Year", 2020)

plots.plot(top_2019.column("Abv Month"), top_2019.column("Avg_players"), label="2019")
plots.plot(top_2020.column("Abv Month"), top_2020.column("Avg_players"), label="2020")
plots.xlabel("Month")
plots.ylabel("Number of Average Monthly Players")
plots.legend()
plots.title("Average Players for #1 Game of the Month")
plots.show()

# %% [markdown]
# **Answer -** This plot shows the increase in average monthly players for that month's number one game. Although this is not a representation of the total number of people playing video games, we can observe a large increase in average players in 2020. There is a major spike beginning in March 2020 with player counts continuing to stay a consistent 100,000-200,000 higher than the previous year. This appears to be consistent with the COVID-19 lockdown timeline. One thing to consider is that this graph only shows the top game for each month and could easily be influenced by the release of a popular game.
